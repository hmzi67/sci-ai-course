# %%
def mean_fun(n, *x):
    return sum(x) / n

mean_fun(5, 3, 3, 3, 4, 4)
# Out:
# 3.4

# %%
def even_no(x):
    count = 0
    for i in x:
        if i % 2 == 0:
            count += 1
    return count

even_no([1, 2, 4, 6, 8, 10])
# Out:
# 5
