# %% [markdown]
# # TASK 1

# %%
import scipy.stats as st

no_of_trials = 10
success = 2
p = 1/6

# %%
st.binom.pmf(k=success, n=no_of_trials, p=p)
# Out:
# 0.2907100492017222

# %% [markdown]
# # TASK 2

# %%
trials = 15
success = 3
p = 1/6

st.binom.cdf(k=success, n=trials, p=p)
# Out:
# 0.7684807827834736

# %% [markdown]
# # TASK 3

# %%
lamb = 5
events = 3

st.poisson.pmf(events, lamb)
# Out:
# 0.1403738958142805

# %% [markdown]
# # TASK 4

# %%
lamb = 3
events = 2

st.poisson.cdf(events, lamb)
# Out:
# 0.42319008112684364

# %% [markdown]
# # TASK 5

# %%
import numpy as np
import pandas as pd

eye_count = np.array([150, 120, 80, 50])
eye_color = pd.Series(eye_count, index=['Brown', 'Blue', 'Hazel', 'Green'])

# %%
eye_color

brown =  eye_count[0] / sum(eye_count)
blue =  eye_count[0] / sum(eye_count)
hazel =  eye_count[0] / sum(eye_count)
green =  eye_count[0] / sum(eye_count)

proportion = brown, blue, hazel, green

eye_color = pd.Series(eye_count, index=proportion)

eye_color
# Out:
# 0.375    150
# 0.375    120
# 0.375     80
# 0.375     50
# dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
sns.countplot(data=titanic, x='survived')
plt.title('Survival Count')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()

# %%
sns.histplot(titanic['age'], bins=10)
plt.title('Age Distribution of Passengers')
plt.xlabel('AGE')
plt.ylabel('FREQUENCY') 
plt.show()

# %%
plt.scatter(titanic['age'], titanic['fare'])
plt.title('Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.show()

# %%
sns.boxplot(x=titanic['survived'], y=titanic['fare'])
plt.xlabel('Survival Status')
plt.ylabel('Fare')
plt.title('Survival Status vs. Fare')
plt.show()

# %%
correlation = titanic[['age', 'fare']].corr()
correlation
# Out:
#            age      fare
# age   1.000000  0.096067
# fare  0.096067  1.000000

# %%
cross_tab = pd.crosstab(titanic['pclass'], titanic['survived'])
cross_tab
# Out:
# survived    0    1
# pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.catplot(x='sex', hue='survived', kind='count', data=titanic)
plt.show()

# %%
group = titanic.groupby(['pclass', 'survived'])
pclass_survived = group.size().unstack()
sns.heatmap(pclass_survived, annot=True, fmt='d')
plt.show()

# %%
sns.violinplot(x = 'sex', y='age', hue='survived', data=titanic, split=True)
plt.show()

# %%
sns.catplot(x='embarked', hue = 'survived', kind = 'count' ,col='pclass' , data = titanic)
plt.show()

# %%
plt.figure(figsize=(10,6))
# sns.heatmap(titanic.corr(), annot= True)
sns.histplot(data=titanic, x='age', kde=True, hue='sex')
plt.title('Age Distribution by Sex')
plt.xlabel="age"
plt.ylabel='distribution'
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=titanic, x='class', y='survived', hue='sex')
plt.title('Survival Rate by Passenger Class and Gender')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=titanic, x='embarked', hue='survived')
plt.title('Survival Count based on Embarkation Port')
plt.show()

# %% [markdown]
# TASK

# %%
titanic['deck'].unique()
# Out:
# [NaN, 'C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=titanic, x='deck', hue='survived')
plt.title('Survival Count based on Embarkation Port')
plt.show()

# %%
group = titanic.groupby(['who', 'survived'])
pclass_survived = group.size().unstack()
sns.heatmap(pclass_survived, annot=True, fmt='d')
plt.show()

# %%
group.size().unstack()
# Out:
# survived    0    1
# who
# child      34   49
# man       449   88
# woman      66  205

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']
