# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import warnings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('mpg.csv')
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
data.shape
# Out:
# (398, 9)

# %%
sns.distplot(data['mpg'], kde=False, rug=False, bins= 50, color='red')
plt.show()

# %%
sns.distplot(data['mpg'], kde=True, rug=False, bins= 50, color='green')
plt.show()

# %%
sns.distplot(data['mpg'], kde=False, rug=True, bins= 50, color='orange')
plt.show()

# %%
sns.kdeplot(data.mpg, color='orange')
plt.show()

# %%
sns.jointplot(x='weight', y='mpg', data=data, color='purple', kind='scatter')
plt.show()

# %%
sns.jointplot(x='weight', y='mpg', data=data, color='purple', kind='reg')
plt.show()

# %%
sns.lmplot(data, x='weight', y='mpg')
plt.show()

# %%
sns.lmplot(data, x='weight', y='mpg', hue='origin')
plt.show()

# %%
sns.lmplot(data, x='weight', y='mpg', hue='origin', col='origin')
plt.show()

# %%
sns.lmplot(data, x='weight', y='mpg', hue='origin', col='origin', markers=['o', 'v', '^'])
plt.show()

# %%
sns.lmplot(data, x='weight', y='mpg', hue='origin', col='origin', markers=['o', 'v', '^'], scatter_kws={'s':30}, aspect=0.5)
plt.show()

# %%
sns.jointplot(x='weight', y='mpg', data=data, color='green', kind='hex')
plt.show()

# %%
sns.jointplot(x='weight', y='mpg', data=data, color='orange', kind='kde')
plt.show()

# %%
sns.barplot(x='origin', y='mpg', data=data )
plt.show()

# %%
sns.barplot(x='origin',y='mpg',data=data,estimator=np.median)
plt.show()

# %%
sns.countplot(x='origin', data=data, palette='coolwarm')
plt.show()

# %%
sns.countplot(x='origin', data=data, hue='cylinders')
# Out:
# <Axes: xlabel='origin', ylabel='count'>

# %%
sns.boxplot(y='mpg', data=data, color='green')
plt.show()

# %%
sns.boxplot(x='mpg', data=data, color='pink')
plt.show()

# %%
sns.boxplot(x='origin', y='mpg', data=data, palette='coolwarm', notch=True)
plt.show()

# %%
sns.boxplot(x='mpg', y='origin', data=data, palette='coolwarm', notch=True)
plt.show()

# %%
sns.boxplot(x='origin', y='mpg', data=data, palette='coolwarm', hue='cylinders', notch=True)
plt.show()

# %%
sns.violinplot(x='origin', y='mpg', data=data, palette='coolwarm')
plt.show()

# %%
sns.violinplot(x='cylinders', y='horsepower', data=data, palette='coolwarm')
plt.show()

# %%
sns.stripplot(x='cylinders', y='horsepower', data=data, palette='coolwarm')
plt.show()

# %%
sns.swarmplot(x='cylinders', y='horsepower', data=data, palette='coolwarm')
plt.show()

# %%
sns.violinplot(x='cylinders', y='horsepower', data=data)
sns.swarmplot(x='cylinders', y='horsepower', data=data, color='black')
plt.show()

# %%
sns.countplot(x='origin', data=data, palette='cubehelix')
plt.show()
