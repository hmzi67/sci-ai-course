# %% [markdown]
# ### Quantile

# %%
import scipy.stats as st
import numpy as np

# %% [markdown]
# ### 1.1 Standard Normal

# %%
mu = 0
sigma = 1

# %%
alpha = 0.95
st.norm.ppf(alpha, loc=mu, scale=sigma)
# Out:
# 1.6448536269514722

# %%
alpha =
